# %% [markdown]
# ## Libraries

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

from sklearn import set_config; set_config(display='diagram')
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import make_union
from sklearn.compose import make_column_transformer, make_column_selector,ColumnTransformer
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler,RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.model_selection import train_test_split, cross_validate
#from feature_importance import FeatureImportance

# %% [markdown]
# ## Load Data

# %%
df_22 = pd.read_csv('../raw_data/fifa22/players_22.csv')
df_21 = pd.read_csv('../raw_data/fifa22/players_21.csv')
df_20 = pd.read_csv('../raw_data/fifa22/players_20.csv')
df_19 = pd.read_csv('../raw_data/fifa22/players_19.csv')
df_18 = pd.read_csv('../raw_data/fifa22/players_18.csv')
df_17 = pd.read_csv('../raw_data/fifa22/players_17.csv')
df_16 = pd.read_csv('../raw_data/fifa22/players_16.csv')
df_15 = pd.read_csv('../raw_data/fifa22/players_15.csv')
# Out:
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_12564/3992483976.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22 = pd.read_csv('../raw_data/fifa22/players_22.csv')
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_12564/3992483976.py:5: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_18 = pd.read_csv('../raw_data/fifa22/players_18.csv')
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_12564/3992483976.py:7: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_16 = pd.read_csv('../raw_data/fifa22/players_16.csv')
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_12564/3992483976.py:8: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_15 = pd.read_csv('../raw_data/fifa22/players_15.csv')

# %%
for index, col in enumerate(df_22.columns):
    print(f"{col:<26} | ", end="")
    if (index % 3 == 2):
        print("\n", end="")
# Out:
# sofifa_id                  | player_url                 | short_name                 |
# long_name                  | player_positions           | overall                    |
# potential                  | value_eur                  | wage_eur                   |
# age                        | dob                        | height_cm                  |
# weight_kg                  | club_team_id               | club_name                  |
# league_name                | league_level               | club_position              |
# club_jersey_number         | club_loaned_from           | club_joined                |
# club_contract_valid_until  | nationality_id             | nationality_name           |
# nation_team_id             | nation_position            | nation_jersey_number       |
# preferred_foot             | weak_foot                  | skill_moves                |
# international_reputation   | work_rate                  | body_type                  |
# real_face                  | release_clause_eur         | player_tags                |
# player_traits              | pace                       | shooting                   |
# passing                    | dribbling                  | defending                  |
# physic                     | attacking_crossing         | attacking_finishing        |
# attacking_heading_accuracy | attacking_short_passing    | attacking_volleys          |
# skill_dribbling            | skill_curve                | skill_fk_accuracy          |
# skill_long_passing         | skill_ball_control         | movement_acceleration      |
# movement_sprint_speed      | movement_agility           | movement_reactions         |
# movement_balance           | power_shot_power           | power_jumping              |
# power_stamina              | power_strength             | power_long_shots           |
# mentality_aggression       | mentality_interceptions    | mentality_positioning      |
# mentality_vision           | mentality_penalties        | mentality_composure        |
# defending_marking_awareness | defending_standing_tackle  | defending_sliding_tackle   |
# goalkeeping_diving         | goalkeeping_handling       | goalkeeping_kicking        |
# goalkeeping_positioning    | goalkeeping_reflexes       | goalkeeping_speed          |
# ls                         | st                         | rs                         |
# lw                         | lf                         | cf                         |
# rf                         | rw                         | lam                        |
# cam                        | ram                        | lm                         |
# lcm                        | cm                         | rcm                        |
# rm                         | lwb                        | ldm                        |
# cdm                        | rdm                        | rwb                        |
# lb                         | lcb                        | cb                         |
# rcb                        | rb                         | gk                         |
# player_face_url            | club_logo_url              | club_flag_url              |
# nation_logo_url            | nation_flag_url            |

# %%
to_drop = ['club_logo_url','nation_flag_url','club_flag_url','nation_logo_url','player_face_url','dob','player_url',
           'real_face','nation_jersey_number','nation_position','club_loaned_from','long_name','player_url'
          ,'ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm',
           'rm','lwb','ldm', 'cdm','rdm','rwb','lb','lcb','cb','rcb','rb','gk','club_jersey_number','nationality_id','club_jersey_number',
          'goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking' ,'goalkeeping_positioning' ,'goalkeeping_reflexes', 'goalkeeping_speed']

# %%
df22 = df_22.drop(to_drop, axis = 1)
df21 = df_21.drop(to_drop, axis = 1)
df20 = df_20.drop(to_drop, axis = 1)
df19 = df_19.drop(to_drop, axis = 1)
df18 = df_18.drop(to_drop, axis = 1)
df17 = df_17.drop(to_drop, axis = 1)
df16 = df_16.drop(to_drop, axis = 1)
df15 = df_15.drop(to_drop, axis = 1)

# %%
def is_bench(d):
    if d in ("SUB", "RES", ""):
        return True 
    return False

# %%
dfs = [df18, df19, df20, df21,df22,df17,df16,df15]

for frame in dfs:
    frame['is_bench'] = frame['club_position'].apply(is_bench)
    frame['potential_diff'] = frame['potential'] - frame['overall']
    frame[['att_rate', 'def_rate']] = frame['work_rate'].str.split('/', 1, expand=True)

# %%
pos22 = df22['player_positions']
pos21 = df21['player_positions']
pos20 = df20['player_positions']
pos19 = df19['player_positions']
pos18 = df18['player_positions']
pos17 = df17['player_positions']
pos16 = df16['player_positions']
pos15 = df15['player_positions']


pref_pos_22 = []
pref_pos_21 = []
pref_pos_20 = []
pref_pos_19 = []
pref_pos_18 = []
pref_pos_17 = []
pref_pos_16 = []
pref_pos_15 = []

# %%
pos = [pos18, pos19, pos20, pos21,pos22,pos17,pos16,pos15]

for i in pos22:
    a = i.split(',')
    pref_pos_22.append(a[0])
df22['prefered_pos'] = pref_pos_22

for i in pos21:
    a = i.split(',')
    pref_pos_21.append(a[0])
df21['prefered_pos'] = pref_pos_21


for i in pos20:
    a = i.split(',')
    pref_pos_20.append(a[0])
df20['prefered_pos'] = pref_pos_20

for i in pos19:
    a = i.split(',')
    pref_pos_19.append(a[0])
df19['prefered_pos'] = pref_pos_19

for i in pos18:
    a = i.split(',')
    pref_pos_18.append(a[0])
df18['prefered_pos'] = pref_pos_18

for i in pos17:
    a = i.split(',')
    pref_pos_17.append(a[0])
df17['prefered_pos'] = pref_pos_17

for i in pos16:
    a = i.split(',')
    pref_pos_16.append(a[0])
df16['prefered_pos'] = pref_pos_16

for i in pos15:
    a = i.split(',')
    pref_pos_15.append(a[0])
df15['prefered_pos'] = pref_pos_15

# %%
# dfs = [df18, df19, df20, df21,df22,df17,df16,df15]

# for frame in dfs:
#     frame = frame[frame['prefered_pos']!= 'GK']

# print(df22[df22['prefered_pos']!= 'GK'].shape,df22.shape)

# %%
df22 = df22.drop('player_positions', axis = 1)
df21 = df21.drop('player_positions', axis = 1)
df20 = df20.drop('player_positions', axis = 1)
df19 = df19.drop('player_positions', axis = 1)
df18 = df18.drop('player_positions', axis = 1)
df17 = df17.drop('player_positions', axis = 1)
df16 = df16.drop('player_positions', axis = 1)
df15 = df15.drop('player_positions', axis = 1)

df22['prefered_pos'] = df22['prefered_pos'].astype('category')
df21['prefered_pos'] = df21['prefered_pos'].astype('category')
df20['prefered_pos'] = df20['prefered_pos'].astype('category')
df19['prefered_pos'] = df19['prefered_pos'].astype('category')
df18['prefered_pos'] = df18['prefered_pos'].astype('category')
df17['prefered_pos'] = df17['prefered_pos'].astype('category')
df16['prefered_pos'] = df16['prefered_pos'].astype('category')
df15['prefered_pos'] = df15['prefered_pos'].astype('category')

# %% [markdown]
# ## Join Dataframes

# %%
# years = [21, 20]
# for year in years:
#     f'overall_{year}'

# %%
df_all = df22.merge(df21, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_21'))
df_all = df_all.merge(df20, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None,'_20'))
df_all = df_all.merge(df19, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_19'))
df_all = df_all.merge(df18, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_18'))
df_all = df_all.merge(df17, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_17'))
df_all = df_all.merge(df16, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_16'))
df_all = df_all.merge(df15, how='outer',left_on='sofifa_id', right_on='sofifa_id', suffixes=(None, '_15'))

# %%
for index, col in enumerate(df_all.columns):
    print(f"{col:<26} | ", end="")
    if (index % 3 == 2):
        print("\n", end="")
# Out:
# sofifa_id                  | short_name                 | overall                    |
# potential                  | value_eur                  | wage_eur                   |
# age                        | height_cm                  | weight_kg                  |
# club_team_id               | club_name                  | league_name                |
# league_level               | club_position              | club_joined                |
# club_contract_valid_until  | nationality_name           | nation_team_id             |
# preferred_foot             | weak_foot                  | skill_moves                |
# international_reputation   | work_rate                  | body_type                  |
# release_clause_eur         | player_tags                | player_traits              |
# pace                       | shooting                   | passing                    |
# dribbling                  | defending                  | physic                     |
# attacking_crossing         | attacking_finishing        | attacking_heading_accuracy |
# attacking_short_passing    | attacking_volleys          | skill_dribbling            |
# skill_curve                | skill_fk_accuracy          | skill_long_passing         |
# skill_ball_control         | movement_acceleration      | movement_sprint_speed      |
# movement_agility           | movement_reactions         | movement_balance           |
# power_shot_power           | power_jumping              | power_stamina              |
# power_strength             | power_long_shots           | mentality_aggression       |
# mentality_interceptions    | mentality_positioning      | mentality_vision           |
# mentality_penalties        | mentality_composure        | defending_marking_awareness |
# defending_standing_tackle  | defending_sliding_tackle   | is_bench                   |
# potential_diff             | att_rate                   | def_rate                   |
# prefered_pos               | short_name_21              | overall_21                 |
# potential_21               | value_eur_21               | wage_eur_21                |
# age_21                     | height_cm_21               | weight_kg_21               |
# club_team_id_21            | club_name_21               | league_name_21             |
# league_level_21            | club_position_21           | club_joined_21             |
# club_contract_valid_until_21 | nationality_name_21        | nation_team_id_21          |
# preferred_foot_21          | weak_foot_21               | skill_moves_21             |
# international_reputation_21 | work_rate_21               | body_type_21               |
# release_clause_eur_21      | player_tags_21             | player_traits_21           |
# pace_21                    | shooting_21                | passing_21                 |
# dribbling_21               | defending_21               | physic_21                  |
# attacking_crossing_21      | attacking_finishing_21     | attacking_heading_accuracy_21 |
# attacking_short_passing_21 | attacking_volleys_21       | skill_dribbling_21         |
# skill_curve_21             | skill_fk_accuracy_21       | skill_long_passing_21      |
# skill_ball_control_21      | movement_acceleration_21   | movement_sprint_speed_21   |
# movement_agility_21        | movement_reactions_21      | movement_balance_21        |
# power_shot_power_21        | power_jumping_21           | power_stamina_21           |
# power_strength_21          | power_long_shots_21        | mentality_aggression_21    |
# mentality_interceptions_21 | mentality_positioning_21   | mentality_vision_21        |
# mentality_penalties_21     | mentality_composure_21     | defending_marking_awareness_21 |
# defending_standing_tackle_21 | defending_sliding_tackle_21 | is_bench_21                |
# potential_diff_21          | att_rate_21                | def_rate_21                |
# prefered_pos_21            | short_name_20              | overall_20                 |
# potential_20               | value_eur_20               | wage_eur_20                |
# age_20                     | height_cm_20               | weight_kg_20               |
# club_team_id_20            | club_name_20               | league_name_20             |
# league_level_20            | club_position_20           | club_joined_20             |
# club_contract_valid_until_20 | nationality_name_20        | nation_team_id_20          |
# preferred_foot_20          | weak_foot_20               | skill_moves_20             |
# international_reputation_20 | work_rate_20               | body_type_20               |
# release_clause_eur_20      | player_tags_20             | player_traits_20           |
# pace_20                    | shooting_20                | passing_20                 |
# dribbling_20               | defending_20               | physic_20                  |
# attacking_crossing_20      | attacking_finishing_20     | attacking_heading_accuracy_20 |
# attacking_short_passing_20 | attacking_volleys_20       | skill_dribbling_20         |
# skill_curve_20             | skill_fk_accuracy_20       | skill_long_passing_20      |
# skill_ball_control_20      | movement_acceleration_20   | movement_sprint_speed_20   |
# movement_agility_20        | movement_reactions_20      | movement_balance_20        |
# power_shot_power_20        | power_jumping_20           | power_stamina_20           |
# power_strength_20          | power_long_shots_20        | mentality_aggression_20    |
# mentality_interceptions_20 | mentality_positioning_20   | mentality_vision_20        |
# mentality_penalties_20     | mentality_composure_20     | defending_marking_awareness_20 |
# defending_standing_tackle_20 | defending_sliding_tackle_20 | is_bench_20                |
# potential_diff_20          | att_rate_20                | def_rate_20                |
# prefered_pos_20            | short_name_19              | overall_19                 |
# potential_19               | value_eur_19               | wage_eur_19                |
# age_19                     | height_cm_19               | weight_kg_19               |
# club_team_id_19            | club_name_19               | league_name_19             |
# league_level_19            | club_position_19           | club_joined_19             |
# club_contract_valid_until_19 | nationality_name_19        | nation_team_id_19          |
# preferred_foot_19          | weak_foot_19               | skill_moves_19             |
# international_reputation_19 | work_rate_19               | body_type_19               |
# release_clause_eur_19      | player_tags_19             | player_traits_19           |
# pace_19                    | shooting_19                | passing_19                 |
# dribbling_19               | defending_19               | physic_19                  |
# attacking_crossing_19      | attacking_finishing_19     | attacking_heading_accuracy_19 |
# attacking_short_passing_19 | attacking_volleys_19       | skill_dribbling_19         |
# skill_curve_19             | skill_fk_accuracy_19       | skill_long_passing_19      |
# skill_ball_control_19      | movement_acceleration_19   | movement_sprint_speed_19   |
# movement_agility_19        | movement_reactions_19      | movement_balance_19        |
# power_shot_power_19        | power_jumping_19           | power_stamina_19           |
# power_strength_19          | power_long_shots_19        | mentality_aggression_19    |
# mentality_interceptions_19 | mentality_positioning_19   | mentality_vision_19        |
# mentality_penalties_19     | mentality_composure_19     | defending_marking_awareness_19 |
# defending_standing_tackle_19 | defending_sliding_tackle_19 | is_bench_19                |
# potential_diff_19          | att_rate_19                | def_rate_19                |
# prefered_pos_19            | short_name_18              | overall_18                 |
# potential_18               | value_eur_18               | wage_eur_18                |
# age_18                     | height_cm_18               | weight_kg_18               |
# club_team_id_18            | club_name_18               | league_name_18             |
# league_level_18            | club_position_18           | club_joined_18             |
# club_contract_valid_until_18 | nationality_name_18        | nation_team_id_18          |
# preferred_foot_18          | weak_foot_18               | skill_moves_18             |
# international_reputation_18 | work_rate_18               | body_type_18               |
# release_clause_eur_18      | player_tags_18             | player_traits_18           |
# pace_18                    | shooting_18                | passing_18                 |
# dribbling_18               | defending_18               | physic_18                  |
# attacking_crossing_18      | attacking_finishing_18     | attacking_heading_accuracy_18 |
# attacking_short_passing_18 | attacking_volleys_18       | skill_dribbling_18         |
# skill_curve_18             | skill_fk_accuracy_18       | skill_long_passing_18      |
# skill_ball_control_18      | movement_acceleration_18   | movement_sprint_speed_18   |
# movement_agility_18        | movement_reactions_18      | movement_balance_18        |
# power_shot_power_18        | power_jumping_18           | power_stamina_18           |
# power_strength_18          | power_long_shots_18        | mentality_aggression_18    |
# mentality_interceptions_18 | mentality_positioning_18   | mentality_vision_18        |
# mentality_penalties_18     | mentality_composure_18     | defending_marking_awareness_18 |
# defending_standing_tackle_18 | defending_sliding_tackle_18 | is_bench_18                |
# potential_diff_18          | att_rate_18                | def_rate_18                |
# prefered_pos_18            | short_name_17              | overall_17                 |
# potential_17               | value_eur_17               | wage_eur_17                |
# age_17                     | height_cm_17               | weight_kg_17               |
# club_team_id_17            | club_name_17               | league_name_17             |
# league_level_17            | club_position_17           | club_joined_17             |
# club_contract_valid_until_17 | nationality_name_17        | nation_team_id_17          |
# preferred_foot_17          | weak_foot_17               | skill_moves_17             |
# international_reputation_17 | work_rate_17               | body_type_17               |
# release_clause_eur_17      | player_tags_17             | player_traits_17           |
# pace_17                    | shooting_17                | passing_17                 |
# dribbling_17               | defending_17               | physic_17                  |
# attacking_crossing_17      | attacking_finishing_17     | attacking_heading_accuracy_17 |
# attacking_short_passing_17 | attacking_volleys_17       | skill_dribbling_17         |
# skill_curve_17             | skill_fk_accuracy_17       | skill_long_passing_17      |
# skill_ball_control_17      | movement_acceleration_17   | movement_sprint_speed_17   |
# movement_agility_17        | movement_reactions_17      | movement_balance_17        |
# power_shot_power_17        | power_jumping_17           | power_stamina_17           |
# power_strength_17          | power_long_shots_17        | mentality_aggression_17    |
# mentality_interceptions_17 | mentality_positioning_17   | mentality_vision_17        |
# mentality_penalties_17     | mentality_composure_17     | defending_marking_awareness_17 |
# defending_standing_tackle_17 | defending_sliding_tackle_17 | is_bench_17                |
# potential_diff_17          | att_rate_17                | def_rate_17                |
# prefered_pos_17            | short_name_16              | overall_16                 |
# potential_16               | value_eur_16               | wage_eur_16                |
# age_16                     | height_cm_16               | weight_kg_16               |
# club_team_id_16            | club_name_16               | league_name_16             |
# league_level_16            | club_position_16           | club_joined_16             |
# club_contract_valid_until_16 | nationality_name_16        | nation_team_id_16          |
# preferred_foot_16          | weak_foot_16               | skill_moves_16             |
# international_reputation_16 | work_rate_16               | body_type_16               |
# release_clause_eur_16      | player_tags_16             | player_traits_16           |
# pace_16                    | shooting_16                | passing_16                 |
# dribbling_16               | defending_16               | physic_16                  |
# attacking_crossing_16      | attacking_finishing_16     | attacking_heading_accuracy_16 |
# attacking_short_passing_16 | attacking_volleys_16       | skill_dribbling_16         |
# skill_curve_16             | skill_fk_accuracy_16       | skill_long_passing_16      |
# skill_ball_control_16      | movement_acceleration_16   | movement_sprint_speed_16   |
# movement_agility_16        | movement_reactions_16      | movement_balance_16        |
# power_shot_power_16        | power_jumping_16           | power_stamina_16           |
# power_strength_16          | power_long_shots_16        | mentality_aggression_16    |
# mentality_interceptions_16 | mentality_positioning_16   | mentality_vision_16        |
# mentality_penalties_16     | mentality_composure_16     | defending_marking_awareness_16 |
# defending_standing_tackle_16 | defending_sliding_tackle_16 | is_bench_16                |
# potential_diff_16          | att_rate_16                | def_rate_16                |
# prefered_pos_16            | short_name_15              | overall_15                 |
# potential_15               | value_eur_15               | wage_eur_15                |
# age_15                     | height_cm_15               | weight_kg_15               |
# club_team_id_15            | club_name_15               | league_name_15             |
# league_level_15            | club_position_15           | club_joined_15             |
# club_contract_valid_until_15 | nationality_name_15        | nation_team_id_15          |
# preferred_foot_15          | weak_foot_15               | skill_moves_15             |
# international_reputation_15 | work_rate_15               | body_type_15               |
# release_clause_eur_15      | player_tags_15             | player_traits_15           |
# pace_15                    | shooting_15                | passing_15                 |
# dribbling_15               | defending_15               | physic_15                  |
# attacking_crossing_15      | attacking_finishing_15     | attacking_heading_accuracy_15 |
# attacking_short_passing_15 | attacking_volleys_15       | skill_dribbling_15         |
# skill_curve_15             | skill_fk_accuracy_15       | skill_long_passing_15      |
# skill_ball_control_15      | movement_acceleration_15   | movement_sprint_speed_15   |
# movement_agility_15        | movement_reactions_15      | movement_balance_15        |
# power_shot_power_15        | power_jumping_15           | power_stamina_15           |
# power_strength_15          | power_long_shots_15        | mentality_aggression_15    |
# mentality_interceptions_15 | mentality_positioning_15   | mentality_vision_15        |
# mentality_penalties_15     | mentality_composure_15     | defending_marking_awareness_15 |
# defending_standing_tackle_15 | defending_sliding_tackle_15 | is_bench_15                |
# potential_diff_15          | att_rate_15                | def_rate_15                |
# prefered_pos_15            |

# %%
df_all
# Out:
#        sofifa_id         short_name  overall  potential    value_eur  \
# 0         158023           L. Messi     93.0       93.0   78000000.0
# 1         188545     R. Lewandowski     92.0       92.0  119500000.0
# 2          20801  Cristiano Ronaldo     91.0       91.0   45000000.0
# 3         190871          Neymar Jr     91.0       91.0  129000000.0
# 4         192985       K. De Bruyne     91.0       91.0  125500000.0
# ...          ...                ...      ...        ...          ...
# 45624     225340                NaN      NaN        NaN          NaN
# 45625     221338                NaN      NaN        NaN          NaN
# 45626     224829                NaN      NaN        NaN          NaN
# 45627     220549                NaN      NaN        NaN          NaN
# 45628     201197                NaN      NaN        NaN          NaN
#
#        wage_eur   age  height_cm  weight_kg  club_team_id  ...  \
# 0      320000.0  34.0      170.0       72.0          73.0  ...
# 1      270000.0  32.0      185.0       81.0          21.0  ...
# 2      270000.0  36.0      187.0       83.0          11.0  ...
# 3      270000.0  29.0      175.0       68.0          73.0  ...
# 4      350000.0  30.0      181.0       70.0          10.0  ...
# ...         ...   ...        ...        ...           ...  ...
# 45624       NaN   NaN        NaN        NaN           NaN  ...
# 45625       NaN   NaN        NaN        NaN           NaN  ...
# 45626       NaN   NaN        NaN        NaN           NaN  ...
# 45627       NaN   NaN        NaN        NaN           NaN  ...
# 45628       NaN   NaN        NaN        NaN           NaN  ...
#
#       mentality_penalties_15 mentality_composure_15  \
# 0                       76.0                    NaN
# 1                       77.0                    NaN
# 2                       85.0                    NaN
# 3                       81.0                    NaN
# 4                       75.0                    NaN
# ...                      ...                    ...
# 45624                   31.0                    NaN
# 45625                   37.0                    NaN
# 45626                   29.0                    NaN
# 45627                   59.0                    NaN
# 45628                   55.0                    NaN
#
#        defending_marking_awareness_15 defending_standing_tackle_15  \
# 0                                25.0                         21.0
# 1                                25.0                         42.0
# 2                                22.0                         31.0
# 3                                21.0                         24.0
# 4                                37.0                         39.0
# ...                               ...                          ...
# 45624                            40.0                         52.0
# 45625                            39.0                         44.0
# 45626                            25.0                         25.0
# 45627                            25.0                         25.0
# 45628                            27.0                         34.0
#
#       defending_sliding_tackle_15  is_bench_15 potential_diff_15  att_rate_15  \
# 0                            20.0        False               2.0       Medium
# 1                            25.0        False               2.0         High
# 2                            23.0        False               0.0         High
# 3                            33.0        False               5.0         High
# 4                            40.0        False               5.0         High
# ...                           ...          ...               ...          ...
# 45624                        51.0         True               6.0       Medium
# 45625                        43.0         True              12.0          Low
# 45626                        25.0         True               6.0       Medium
# 45627                        25.0         True              13.0       Medium
# 45628                        29.0         True               0.0       Medium
#
#       def_rate_15  prefered_pos_15
# 0             Low               CF
# 1          Medium               ST
# 2             Low               LW
# 3          Medium               LW
# 4          Medium              CAM
# ...           ...              ...
# 45624      Medium               CB
# 45625      Medium               CB
# 45626      Medium               GK
# 45627      Medium               LM
# 45628      Medium               CM
#
# [45629 rows x 529 columns]

# %%
df_plot=df_all[['sofifa_id','overall_15','overall_16','overall_17','overall_18','overall_19','overall_20','overall_21','overall']]

# %%
df_all
# Out:
#        sofifa_id         short_name  overall  potential    value_eur  \
# 0         158023           L. Messi     93.0       93.0   78000000.0
# 1         188545     R. Lewandowski     92.0       92.0  119500000.0
# 2          20801  Cristiano Ronaldo     91.0       91.0   45000000.0
# 3         190871          Neymar Jr     91.0       91.0  129000000.0
# 4         192985       K. De Bruyne     91.0       91.0  125500000.0
# ...          ...                ...      ...        ...          ...
# 45624     225340                NaN      NaN        NaN          NaN
# 45625     221338                NaN      NaN        NaN          NaN
# 45626     224829                NaN      NaN        NaN          NaN
# 45627     220549                NaN      NaN        NaN          NaN
# 45628     201197                NaN      NaN        NaN          NaN
#
#        wage_eur   age  height_cm  weight_kg  club_team_id  ...  \
# 0      320000.0  34.0      170.0       72.0          73.0  ...
# 1      270000.0  32.0      185.0       81.0          21.0  ...
# 2      270000.0  36.0      187.0       83.0          11.0  ...
# 3      270000.0  29.0      175.0       68.0          73.0  ...
# 4      350000.0  30.0      181.0       70.0          10.0  ...
# ...         ...   ...        ...        ...           ...  ...
# 45624       NaN   NaN        NaN        NaN           NaN  ...
# 45625       NaN   NaN        NaN        NaN           NaN  ...
# 45626       NaN   NaN        NaN        NaN           NaN  ...
# 45627       NaN   NaN        NaN        NaN           NaN  ...
# 45628       NaN   NaN        NaN        NaN           NaN  ...
#
#       mentality_penalties_15 mentality_composure_15  \
# 0                       76.0                    NaN
# 1                       77.0                    NaN
# 2                       85.0                    NaN
# 3                       81.0                    NaN
# 4                       75.0                    NaN
# ...                      ...                    ...
# 45624                   31.0                    NaN
# 45625                   37.0                    NaN
# 45626                   29.0                    NaN
# 45627                   59.0                    NaN
# 45628                   55.0                    NaN
#
#        defending_marking_awareness_15 defending_standing_tackle_15  \
# 0                                25.0                         21.0
# 1                                25.0                         42.0
# 2                                22.0                         31.0
# 3                                21.0                         24.0
# 4                                37.0                         39.0
# ...                               ...                          ...
# 45624                            40.0                         52.0
# 45625                            39.0                         44.0
# 45626                            25.0                         25.0
# 45627                            25.0                         25.0
# 45628                            27.0                         34.0
#
#       defending_sliding_tackle_15  is_bench_15 potential_diff_15  att_rate_15  \
# 0                            20.0        False               2.0       Medium
# 1                            25.0        False               2.0         High
# 2                            23.0        False               0.0         High
# 3                            33.0        False               5.0         High
# 4                            40.0        False               5.0         High
# ...                           ...          ...               ...          ...
# 45624                        51.0         True               6.0       Medium
# 45625                        43.0         True              12.0          Low
# 45626                        25.0         True               6.0       Medium
# 45627                        25.0         True              13.0       Medium
# 45628                        29.0         True               0.0       Medium
#
#       def_rate_15  prefered_pos_15
# 0             Low               CF
# 1          Medium               ST
# 2             Low               LW
# 3          Medium               LW
# 4          Medium              CAM
# ...           ...              ...
# 45624      Medium               CB
# 45625      Medium               CB
# 45626      Medium               GK
# 45627      Medium               LM
# 45628      Medium               CM
#
# [45629 rows x 529 columns]

# %%
df_all['is_bench_21'] = df_all['is_bench_21'].astype('bool')
df_all['is_bench_20'] = df_all['is_bench_20'].astype('bool')
df_all['is_bench_19'] = df_all['is_bench_19'].astype('bool')
df_all['is_bench_18'] = df_all['is_bench_18'].astype('bool')
df_all['is_bench_17'] = df_all['is_bench_17'].astype('bool')
df_all['is_bench_16'] = df_all['is_bench_16'].astype('bool')
df_all['is_bench_15'] = df_all['is_bench_15'].astype('bool')

# %%
df_all.select_dtypes("bool").nunique()
# Out:
# is_bench_21    2
# is_bench_20    2
# is_bench_19    2
# is_bench_18    2
# is_bench_17    2
# is_bench_16    2
# is_bench_15    2
# dtype: int64

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45629 entries, 0 to 45628
# Columns: 529 entries, sofifa_id to prefered_pos_15
# dtypes: bool(7), category(8), float64(408), int64(1), object(105)
# memory usage: 179.9+ MB

# %%
# df_all.select_dtypes("float64").nunique()

df_all.work_rate.value_counts()
# Out:
# Medium/Medium    10015
# High/Medium       3661
# Medium/High       1880
# High/High         1099
# Medium/Low         810
# High/Low           808
# Low/Medium         466
# Low/High           455
# Low/Low             45
# Name: work_rate, dtype: int64

# %%
feat_categorical_nunique = df_all.select_dtypes("object").nunique()
feat_categorical_nunique
# Out:
# short_name          18145
# club_name             701
# league_name            55
# club_position          29
# club_joined          1845
#                     ...
# body_type_15           10
# player_tags_15         59
# player_traits_15      829
# att_rate_15             3
# def_rate_15             3
# Length: 105, dtype: int64

# %%
feat_categorical_small = feat_categorical_nunique[feat_categorical_nunique < 10]
feat_categorical_small
# Out:
# preferred_foot       2
# work_rate            9
# is_bench             2
# att_rate             3
# def_rate             3
# preferred_foot_21    2
# work_rate_21         9
# att_rate_21          3
# def_rate_21          3
# preferred_foot_20    2
# work_rate_20         9
# att_rate_20          3
# def_rate_20          3
# preferred_foot_19    2
# work_rate_19         9
# att_rate_19          3
# def_rate_19          3
# preferred_foot_18    2
# work_rate_18         9
# att_rate_18          3
# def_rate_18          3
# preferred_foot_17    2
# work_rate_17         9
# att_rate_17          3
# def_rate_17          3
# preferred_foot_16    2
# work_rate_16         9
# att_rate_16          3
# def_rate_16          3
# preferred_foot_15    2
# work_rate_15         9
# att_rate_15          3
# def_rate_15          3
# dtype: int64

# %%
wk_drop = ['work_rate','work_rate_21','work_rate_20','work_rate_19',
           'work_rate_18','work_rate_17','work_rate_16','work_rate_15']

df_all = df_all.drop(wk_drop, axis = 1)

# %%
df_all[['short_name','short_name_20','short_name_15','short_name_16','short_name_17']]
# Out:
#               short_name      short_name_20      short_name_15  \
# 0               L. Messi           L. Messi           L. Messi
# 1         R. Lewandowski     R. Lewandowski     R. Lewandowski
# 2      Cristiano Ronaldo  Cristiano Ronaldo  Cristiano Ronaldo
# 3              Neymar Jr          Neymar Jr             Neymar
# 4           K. De Bruyne       K. De Bruyne       K. De Bruyne
# ...                  ...                ...                ...
# 45624                NaN                NaN         B. Jackson
# 45625                NaN                NaN         M. Fissore
# 45626                NaN                NaN        H. Reynolds
# 45627                NaN                NaN          L. Davies
# 45628                NaN                NaN         P. Tisdale
#
#            short_name_16      short_name_17
# 0               L. Messi           L. Messi
# 1         R. Lewandowski     R. Lewandowski
# 2      Cristiano Ronaldo  Cristiano Ronaldo
# 3                 Neymar             Neymar
# 4           K. De Bruyne       K. De Bruyne
# ...                  ...                ...
# 45624                NaN                NaN
# 45625                NaN                NaN
# 45626                NaN                NaN
# 45627                NaN                NaN
# 45628                NaN                NaN
#
# [45629 rows x 5 columns]

# %% [markdown]
# ## Pipeline

# %%
# Preprocessor

# num_transformer = make_pipeline(SimpleImputer(), MinMaxScaler())

# cat_transformer = OneHotEncoder(handle_unknown='ignore', sparse=True)
SimpleImputer.get_feature_names_out = (lambda self, names=None:
                                       self.feature_names_in_)

num_transformer = make_pipeline(SimpleImputer(strategy='mean'), StandardScaler())
num_col = make_column_selector(dtype_include=['int64','float64'])

cat_transformer = make_pipeline(SimpleImputer(strategy = 'most_frequent')
                                ,OneHotEncoder(handle_unknown='ignore', sparse=True)
                               )

cat_col = make_column_selector(dtype_include=['object','bool','category'])

preproc = make_column_transformer(
    (num_transformer, make_column_selector(dtype_include=['float64','int64'])),
    (cat_transformer, cat_col),
    remainder='passthrough')



# Add Estimator
# pipe = make_pipeline(preproc, Lasso(alpha=0.2))
pipe = make_pipeline(preproc, LinearRegression())
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x151207ac0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x1130db5e0>)])),
#                 ('linearregression', LinearRegression())])

# %%
## Filter df_all to keep overall of 2022 and features of 2021


# 2021 features
# X=df_all.drop(columns='overall')
cols = [col for col in df_all.columns if '_21' in col or 'value_eur' == col]

df = df_all[cols]
new_df = df[df['value_eur'].notnull()&df['short_name_21'].notnull()]
# df_all[cols].isna().sum()

# # new_df = df_all[cols].dropna(axis=0, how='all')
# # X = new_df.drop(columns='overall').dropna(axis=0)
X = new_df.drop(columns='value_eur')
# # cols
# # # X = df_all[cols].dropna(axis=0,how='all')
y = new_df.value_eur
# # # X
# # X

# %%
y=np.log(y)
y
# Out:
# 0        2.899894
# 1        2.923099
# 2        2.869158
# 3        2.927203
# 4        2.925729
#            ...
# 19180    2.451715
# 19185    2.423898
# 19188    2.412000
# 19220    2.443470
# 19221    2.451715
# Name: value_eur, Length: 13247, dtype: float64

# %%
X
# Out:
#            short_name_21  overall_21  potential_21  value_eur_21  wage_eur_21  \
# 0               L. Messi        93.0          93.0   103500000.0     560000.0
# 1         R. Lewandowski        91.0          91.0   111000000.0     240000.0
# 2      Cristiano Ronaldo        92.0          92.0    63000000.0     220000.0
# 3              Neymar Jr        91.0          91.0   132000000.0     270000.0
# 4           K. De Bruyne        91.0          91.0   129000000.0     370000.0
# ...                  ...         ...           ...           ...          ...
# 19180          Zhang Wei        49.0          57.0      100000.0       1000.0
# 19185        P. McGarvey        48.0          58.0       80000.0        500.0
# 19188          Guo Yunqi        48.0          53.0       70000.0       1000.0
# 19220         D. Collins        48.0          61.0      110000.0        500.0
# 19221       Wang Zhen'ao        47.0          57.0      100000.0       2000.0
#
#        age_21  height_cm_21  weight_kg_21  club_team_id_21  \
# 0        33.0         170.0          72.0            241.0
# 1        31.0         184.0          80.0             21.0
# 2        35.0         187.0          83.0             45.0
# 3        28.0         175.0          68.0             73.0
# 4        29.0         181.0          70.0             10.0
# ...       ...           ...           ...              ...
# 19180    20.0         186.0          74.0         112978.0
# 19185    16.0         180.0          76.0         111131.0
# 19188    23.0         175.0          68.0         112985.0
# 19220    19.0         174.0          68.0            563.0
# 19221    20.0         175.0          69.0         112378.0
#
#                             club_name_21  ... mentality_penalties_21  \
# 0                           FC Barcelona  ...                   75.0
# 1                      FC Bayern München  ...                   88.0
# 2                               Juventus  ...                   84.0
# 3                    Paris Saint-Germain  ...                   92.0
# 4                        Manchester City  ...                   84.0
# ...                                  ...  ...                    ...
# 19180                           Hebei FC  ...                   36.0
# 19185                         Finn Harps  ...                   17.0
# 19188      Shijiazhuang Ever Bright F.C.  ...                   41.0
# 19220                       Sligo Rovers  ...                   40.0
# 19221  Dalian Professional Football Club  ...                   46.0
#
#        mentality_composure_21 defending_marking_awareness_21  \
# 0                        96.0                           32.0
# 1                        88.0                           35.0
# 2                        95.0                           28.0
# 3                        93.0                           35.0
# 4                        91.0                           68.0
# ...                       ...                            ...
# 19180                    43.0                           46.0
# 19185                    38.0                            5.0
# 19188                    40.0                           43.0
# 19220                    50.0                           39.0
# 19221                    45.0                           26.0
#
#       defending_standing_tackle_21  defending_sliding_tackle_21 is_bench_21  \
# 0                             35.0                         24.0       False
# 1                             42.0                         19.0       False
# 2                             32.0                         24.0       False
# 3                             30.0                         29.0       False
# 4                             65.0                         53.0       False
# ...                            ...                          ...         ...
# 19180                         52.0                         46.0        True
# 19185                         10.0                         13.0        True
# 19188                         48.0                         44.0        True
# 19220                         29.0                         27.0        True
# 19221                         32.0                         42.0        True
#
#        potential_diff_21 att_rate_21  def_rate_21  prefered_pos_21
# 0                    0.0      Medium          Low               RW
# 1                    0.0        High       Medium               ST
# 2                    0.0        High          Low               ST
# 3                    0.0        High       Medium               LW
# 4                    0.0        High         High              CAM
# ...                  ...         ...          ...              ...
# 19180                8.0      Medium       Medium               RM
# 19185               10.0      Medium       Medium               GK
# 19188                5.0         Low          Low               CM
# 19220               13.0      Medium       Medium               ST
# 19221               10.0      Medium       Medium               RW
#
# [13247 rows x 65 columns]

# %%
X_train22, X_test22, y_train22, y_test22 = train_test_split(X, y, test_size=0.3,random_state=10)

# %%
pipe.fit(X_train22,y_train22)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x151207ac0>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x1130db5e0>)])),
#                 ('linearregression', LinearRegression())])

# %%
plt.barh(pipe[:-1].get_feature_names_out()[0:21],pipe[-1].coef_[0:21])
# Out:
# <BarContainer object of 21 artists>

# %%
#(new_df.groupby('age_21','league_level_21')['value_eur'].agg(['var','median']))

# %%
len(pipe[:-1].get_feature_names_out())
# Out:
# 12140

# %%
pipe.predict(X_test22.iloc[0:2])
# Out:
# array([2276048.98009301, 1615618.50947348])

# %%
# pipe[-1].coef_[pipe[-1].coef_ != 0]
# plt.bar(pipe.feature_names_in_, pipe[-1].coef_)
# pipe.get_feature_names_out()
# pipe[:-1].get_feature_names_out()
# pipe[:-1].get_feature_names_out()
# pipe[:-1].named_steps["columntransformer"].get_feature_names_out()

# %%
from sklearn.model_selection import cross_val_score,cross_validate

# pipe.fit(X,y)
# pipe.score(X,y)
# pipe.predict(new_data)
cv_results = cross_validate(pipe, X_train22, y_train22, cv=5, 
                            scoring=['neg_mean_absolute_error','r2']
                           )
pd.DataFrame(cv_results)
# Out:
#    fit_time  score_time  test_neg_mean_absolute_error   test_r2
# 0  0.824220    0.025249                     -0.027963  0.814353
# 1  0.786114    0.023040                     -0.027773  0.832993
# 2  0.779219    0.025521                     -0.028313  0.816259
# 3  0.766546    0.023950                     -0.027949  0.823797
# 4  0.787710    0.023873                     -0.027639  0.816467

# %%
from sklearn.metrics import SCORERS
sorted(SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %%
predicted_overall = pipe.predict(X_test22)
predicted_overall
# Out:
# array([2.60889688, 2.62762645, 2.63336736, ..., 2.60112635, 2.53455174,
#        2.67588832])

# %%
predictions = {'y_pred' : predicted_overall,
             'y_true': y_test22}

# comparison = pd.dataframe({y_true:[y_test22,pd.Series(predicted_overall,name ='Pred_Overall')],axis = 1)
# comparison

new_df=pd.DataFrame(predictions).sort_index()
new_df.head(30)
# Out:
#        y_pred    y_true
# 0    3.030230  2.899894
# 8    2.932201  2.912928
# 9    2.939595  2.927410
# 16   2.966950  2.914014
# 22   2.870274  2.832835
# 32   2.826718  2.849622
# 40   2.853293  2.909527
# 43   2.934370  2.923099
# 46   2.851974  2.914814
# 53   2.843935  2.878928
# 60   2.938230  2.851401
# 63   2.926505  2.899184
# 66   2.859027  2.906510
# 77   2.836883  2.842897
# 78   2.816812  2.876785
# 79   2.811289  2.866575
# 80   2.813945  2.861004
# 82   2.881476  2.877867
# 84   2.820538  2.869158
# 86   2.894703  2.888072
# 88   2.873933  2.877867
# 93   2.914991  2.899894
# 94   2.920551  2.899540
# 95   2.923324  2.893524
# 97   2.734100  2.802733
# 100  2.802627  2.823516
# 101  2.835678  2.863161
# 104  2.825301  2.857207
# 105  2.816991  2.839742
# 113  2.773046  2.852269

# %%
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y_test22,predicted_overall))
rmse
# Out:
# 0.03756569770760926

# %%
new_df[4:]
# Out:
#              y_pred       y_true
# 22     2.090259e+07   24000000.0
# 32     2.023107e+07   32000000.0
# 40     5.694417e+07   93000000.0
# 43     6.673048e+07  119500000.0
# 46     3.398221e+07  102500000.0
# ...             ...          ...
# 19100 -7.745094e+05      15000.0
# 19111  2.583204e+06     120000.0
# 19128  2.550000e+05      60000.0
# 19129  2.504925e+05      70000.0
# 19179  1.368443e+06     100000.0
#
# [3971 rows x 2 columns]

# %%
len(predicted_overall)
# Out:
# 3975

# %%
plt.scatter(y_test22,predicted_overall)

# %%
plt.plot(range(0,12000000),range(0,12000000))
