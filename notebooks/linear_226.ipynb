# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('df_all_d_new.csv',index_col=[0])

# %%
df_y=pd.read_csv('players_22.csv')
df_y=df_y[['sofifa_id','value_eur']]
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_y
# Out:
#        sofifa_id    value_eur
# 0         158023   78000000.0
# 1         188545  119500000.0
# 2          20801   45000000.0
# 3         190871  129000000.0
# 4         192985  125500000.0
# ...          ...          ...
# 19234     261962      70000.0
# 19235     262040     110000.0
# 19236     262760     100000.0
# 19237     262820     110000.0
# 19238     264540     110000.0
#
# [19239 rows x 2 columns]

# %%
df
# Out:
#        sofifa_id  physic_21  ...  potential_19  overall_19
# 0         158023       65.0  ...          94.0        94.0
# 1         188545       82.0  ...          90.0        90.0
# 2          20801       77.0  ...          94.0        94.0
# 3         190871       59.0  ...          93.0        92.0
# 4         192985       78.0  ...          92.0        91.0
# ...          ...        ...  ...           ...         ...
# 45624     225340        NaN  ...           NaN         NaN
# 45625     221338        NaN  ...           NaN         NaN
# 45626     224829        NaN  ...           NaN         NaN
# 45627     220549        NaN  ...           NaN         NaN
# 45628     201197        NaN  ...           NaN         NaN
#
# [45629 rows x 64 columns]

# %%
df_merged=df.merge(df_y,on='sofifa_id',how='inner')
df_merged=df_merged.fillna(0)
df_merged=df_merged[:15000]
df_merged=df_merged.drop(columns='sofifa_id')

# %%
df_merged_try1=df_merged[:10000]

# %%
#from sklearn.preprocessing import StandardScaler
#std=StandardScaler()
#df_merged_fit=std.fit_transform(df_merged)
#df_merged_fit=pd.DataFrame(df_merged_fit)
#df_merged_fit

# %%
#df_merged_fit=pd.DataFrame(df_merged_fit)
#df_merged_fit

# %%
#X=df_merged_fit.drop(columns=[63])
#y=df_merged_fit[63]

# %%
X=df_merged_try1.drop(columns='value_eur')
y=df_merged_try1.value_eur

# %%
#X_value=X[['value_eur_21','value_eur_20','value_eur_19']]
#X_value=X_value.dropna(how='all')
#X_value

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,
                                               test_size=0.2,
                                               random_state=True)

# %%
X_train.shape
# Out:
# (8000, 63)

# %%
y_train.shape
# Out:
# (8000,)

# %%
from tensorflow.keras import layers,Sequential
from tensorflow import keras

# %%
model=Sequential()
model.add(layers.Dense(4,activation='linear',input_dim=63))
model.add(layers.Dense(3,activation='linear'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss='mse', optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ffabbd27544> in <module>()
# ----> 1 model=Sequential()
#       2 model.add(layers.Dense(4,activation='linear',input_dim=63))
#       3 model.add(layers.Dense(3,activation='linear'))
#       4 model.add(layers.Dense(1,activation='sigmoid'))
#       5 model.compile(loss='mse', optimizer='adam')
#
# NameError: name 'Sequential' is not defined

# %%
#2/24 best one
#model=Sequential()
#model.add(layers.Dense(4,activation='linear',input_dim=63))
#model.add(layers.Dense(3,activation='sigmoid'))
#model.add(layers.Dense(1))
#opt = tf.keras.optimizers.Adam(learning_rate=1e-3, decay=1e-5) #Defining separately to manually modify learning rate
#model.compile(opt, tf.keras.losses.MeanSquaredError(), metrics=['mse','mae'])
#model.compile(loss='mse', optimizer='adam')

# %%
#copy from kaggle
#iii = layers.Input(shape=(63,)) #input 
#d1 = layers.Dense(32, activation="sigmoid", input_dim=65)(iii)
#d2 = layers.Dense(16, activation="sigmoid")(d1)
#final = layers.Dense(1, activation="sigmoid")(d2)
#model = keras.Model(inputs=iii, outputs=final)
#opt = tf.keras.optimizers.Adam(learning_rate=1e-3, decay=1e-5) #Defining separately to manually modify learning rate
#model.compile(opt, tf.keras.losses.MeanSquaredError(), metrics=['mse','mae'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 4)                 256
#
#  dense_10 (Dense)            (None, 3)                 15
#
#  dense_11 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 275
# Trainable params: 275
# Non-trainable params: 0
# _________________________________________________________________

# %%
#opt = tf.keras.optimizers.Adam(learning_rate=1e-3, decay=1e-5) #Defining separately to manually modify learning rate
#model.compile(opt, tf.keras.losses.MeanSquaredError(), metrics=['mse','mae'])

# %%
res1=model.fit(X_train,y_train,
               epochs=80,batch_size=10,
               validation_split=0.3)
# Out:
# Epoch 1/80
# 560/560 [==============================] - 3s 4ms/step - loss: 116700619997184.0000 - val_loss: 127146953539584.0000
# Epoch 2/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700519333888.0000 - val_loss: 127146919985152.0000
# Epoch 3/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700544499712.0000 - val_loss: 127146911596544.0000
# Epoch 4/80
# 560/560 [==============================] - 1s 2ms/step - loss: 116700594831360.0000 - val_loss: 127146894819328.0000
# Epoch 5/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700536111104.0000 - val_loss: 127146878042112.0000
# Epoch 6/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700519333888.0000 - val_loss: 127146852876288.0000
# Epoch 7/80
# 560/560 [==============================] - 1s 2ms/step - loss: 116700469002240.0000 - val_loss: 127146836099072.0000
# Epoch 8/80
# 560/560 [==============================] - 1s 2ms/step - loss: 116700552888320.0000 - val_loss: 127146810933248.0000
# Epoch 9/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700494168064.0000 - val_loss: 127146794156032.0000
# Epoch 10/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700494168064.0000 - val_loss: 127146777378816.0000
# Epoch 11/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700469002240.0000 - val_loss: 127146768990208.0000
# Epoch 12/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700435447808.0000 - val_loss: 127146752212992.0000
# Epoch 13/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700460613632.0000 - val_loss: 127146752212992.0000
# Epoch 14/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700359950336.0000 - val_loss: 127146735435776.0000
# Epoch 15/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700460613632.0000 - val_loss: 127146727047168.0000
# Epoch 16/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700393504768.0000 - val_loss: 127146693492736.0000
# Epoch 17/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700376727552.0000 - val_loss: 127146676715520.0000
# Epoch 18/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700435447808.0000 - val_loss: 127146668326912.0000
# Epoch 19/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700326395904.0000 - val_loss: 127146634772480.0000
# Epoch 20/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700351561728.0000 - val_loss: 127146634772480.0000
# Epoch 21/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700234121216.0000 - val_loss: 127146634772480.0000
# Epoch 22/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700276064256.0000 - val_loss: 127146609606656.0000
# Epoch 23/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700259287040.0000 - val_loss: 127146592829440.0000
# Epoch 24/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700259287040.0000 - val_loss: 127146550886400.0000
# Epoch 25/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700259287040.0000 - val_loss: 127146492166144.0000
# Epoch 26/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700250898432.0000 - val_loss: 127146492166144.0000
# Epoch 27/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700150235136.0000 - val_loss: 127146492166144.0000
# Epoch 28/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700167012352.0000 - val_loss: 127146467000320.0000
# Epoch 29/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700141846528.0000 - val_loss: 127146450223104.0000
# Epoch 30/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700099903488.0000 - val_loss: 127146450223104.0000
# Epoch 31/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700150235136.0000 - val_loss: 127146425057280.0000
# Epoch 32/80
# 560/560 [==============================] - 1s 2ms/step - loss: 116700150235136.0000 - val_loss: 127146425057280.0000
# Epoch 33/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700175400960.0000 - val_loss: 127146391502848.0000
# Epoch 34/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700116680704.0000 - val_loss: 127146383114240.0000
# Epoch 35/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700091514880.0000 - val_loss: 127146366337024.0000
# Epoch 36/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700074737664.0000 - val_loss: 127146349559808.0000
# Epoch 37/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116700141846528.0000 - val_loss: 127146349559808.0000
# Epoch 38/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699965685760.0000 - val_loss: 127146324393984.0000
# Epoch 39/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699982462976.0000 - val_loss: 127146324393984.0000
# Epoch 40/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699957297152.0000 - val_loss: 127146307616768.0000
# Epoch 41/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699940519936.0000 - val_loss: 127146290839552.0000
# Epoch 42/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116700016017408.0000 - val_loss: 127146282450944.0000
# Epoch 43/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699940519936.0000 - val_loss: 127146248896512.0000
# Epoch 44/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699932131328.0000 - val_loss: 127146232119296.0000
# Epoch 45/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699932131328.0000 - val_loss: 127146206953472.0000
# Epoch 46/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699915354112.0000 - val_loss: 127146190176256.0000
# Epoch 47/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699856633856.0000 - val_loss: 127146165010432.0000
# Epoch 48/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699957297152.0000 - val_loss: 127146165010432.0000
# Epoch 49/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699915354112.0000 - val_loss: 127146148233216.0000
# Epoch 50/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699806302208.0000 - val_loss: 127146123067392.0000
# Epoch 51/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699806302208.0000 - val_loss: 127146089512960.0000
# Epoch 52/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699806302208.0000 - val_loss: 127146081124352.0000
# Epoch 53/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699755970560.0000 - val_loss: 127146047569920.0000
# Epoch 54/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699755970560.0000 - val_loss: 127146047569920.0000
# Epoch 55/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699755970560.0000 - val_loss: 127146047569920.0000
# Epoch 56/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699714027520.0000 - val_loss: 127146039181312.0000
# Epoch 57/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699714027520.0000 - val_loss: 127146022404096.0000
# Epoch 58/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699714027520.0000 - val_loss: 127146022404096.0000
# Epoch 59/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699672084480.0000 - val_loss: 127146005626880.0000
# Epoch 60/80
# 560/560 [==============================] - 1s 2ms/step - loss: 116699646918656.0000 - val_loss: 127145988849664.0000
# Epoch 61/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699638530048.0000 - val_loss: 127145988849664.0000
# Epoch 62/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699697250304.0000 - val_loss: 127145980461056.0000
# Epoch 63/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699621752832.0000 - val_loss: 127145921740800.0000
# Epoch 64/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699621752832.0000 - val_loss: 127145921740800.0000
# Epoch 65/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699596587008.0000 - val_loss: 127145904963584.0000
# Epoch 66/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699546255360.0000 - val_loss: 127145904963584.0000
# Epoch 67/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699571421184.0000 - val_loss: 127145896574976.0000
# Epoch 68/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699588198400.0000 - val_loss: 127145863020544.0000
# Epoch 69/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699479146496.0000 - val_loss: 127145846243328.0000
# Epoch 70/80
# 560/560 [==============================] - 2s 3ms/step - loss: 116699546255360.0000 - val_loss: 127145837854720.0000
# Epoch 71/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699512700928.0000 - val_loss: 127145837854720.0000
# Epoch 72/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699512700928.0000 - val_loss: 127145821077504.0000
# Epoch 73/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699428814848.0000 - val_loss: 127145795911680.0000
# Epoch 74/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699479146496.0000 - val_loss: 127145779134464.0000
# Epoch 75/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699403649024.0000 - val_loss: 127145779134464.0000
# Epoch 76/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699487535104.0000 - val_loss: 127145745580032.0000
# Epoch 77/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699378483200.0000 - val_loss: 127145737191424.0000
# Epoch 78/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699353317376.0000 - val_loss: 127145737191424.0000
# Epoch 79/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699453980672.0000 - val_loss: 127145720414208.0000
# Epoch 80/80
# 560/560 [==============================] - 1s 3ms/step - loss: 116699277819904.0000 - val_loss: 127145703636992.0000

# %%
#y_pred=model.predict(X_test)
#pd.DataFrame(y_pred)

# %%
#rmse=np.sqrt(mean_squared_error(y_test,y_pred))
#rmse

# %%
y_pred1=model.predict(X_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred1))
rmse
# Out:
# 12319824.471442074

# %%
X_newtest=df_merged.drop(columns='value_eur')

# %%
X_newtest=X_newtest[:1000]
X_newtest
# Out:
#      physic_21  defending_21  ...  potential_19  overall_19
# 0         65.0          38.0  ...          94.0        94.0
# 1         82.0          43.0  ...          90.0        90.0
# 2         77.0          35.0  ...          94.0        94.0
# 3         59.0          36.0  ...          93.0        92.0
# 4         78.0          64.0  ...          92.0        91.0
# ..         ...           ...  ...           ...         ...
# 995       76.0          78.0  ...          77.0        74.0
# 996       76.0          27.0  ...           0.0         0.0
# 997       76.0          71.0  ...          68.0        64.0
# 998       61.0          62.0  ...          75.0        67.0
# 999       54.0          36.0  ...          75.0        68.0
#
# [1000 rows x 63 columns]

# %%
y_newpred=model.predict(X_newtest)

# %%
y_newpred=pd.DataFrame(y_newpred)

# %%
a=df_y.join(y_newpred)

# %%
a[:100]
# Out:
#     sofifa_id    value_eur           0
# 0      158023   78000000.0  148.565506
# 1      188545  119500000.0  148.565506
# 2       20801   45000000.0  148.565506
# 3      190871  129000000.0  148.565506
# 4      192985  125500000.0  148.565506
# ..        ...          ...         ...
# 95     235212   69500000.0   75.486847
# 96     235243   75000000.0  148.565506
# 97      41236   14500000.0  148.565506
# 98     146536   13000000.0  148.565506
# 99     152729   13500000.0  148.565506
#
# [100 rows x 3 columns]
