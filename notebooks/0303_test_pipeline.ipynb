# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from opti_recruit.pipeline import Trainer

# %%
from opti_recruit.data import get_data,clean_data

# %%
from opti_recruit.data import clean_data,get_data

# %%
import pandas as pd

# %%
df=pd.read_csv('df_all_d_new.csv',index_col=[0])
df=df.dropna(how='any')

# %%
df
# Out:
#        sofifa_id  physic_21  defending_21  dribbling_21  passing_21  \
# 2          20801       77.0          35.0          89.0        81.0
# 4         192985       78.0          64.0          88.0        93.0
# 6         231747       76.0          39.0          91.0        78.0
# 9         202126       83.0          47.0          80.0        80.0
# 10        215914       82.0          86.0          81.0        76.0
# ...          ...        ...           ...           ...         ...
# 19686     191005       70.0          67.0          69.0        71.0
# 19722     211338       71.0          63.0          72.0        70.0
# 19735     216468       57.0          43.0          71.0        72.0
# 19963     178233       68.0          59.0          71.0        65.0
# 21122     221662       65.0          55.0          67.0        63.0
#
#        shooting_21  pace_21  release_clause_eur_21  \
# 2             93.0     89.0             75900000.0
# 4             86.0     76.0            161000000.0
# 6             86.0     96.0            203100000.0
# 9             91.0     68.0            140200000.0
# 10            66.0     77.0             96900000.0
# ...            ...      ...                    ...
# 19686         64.0     68.0              2900000.0
# 19722         67.0     69.0              3900000.0
# 19735         69.0     68.0              4600000.0
# 19963         62.0     66.0              1500000.0
# 21122         66.0     73.0              1500000.0
#
#        international_reputation_21  skill_moves_21  ...  \
# 2                              5.0             5.0  ...
# 4                              4.0             4.0  ...
# 6                              3.0             5.0  ...
# 9                              3.0             3.0  ...
# 10                             3.0             2.0  ...
# ...                            ...             ...  ...
# 19686                          2.0             3.0  ...
# 19722                          1.0             3.0  ...
# 19735                          1.0             3.0  ...
# 19963                          1.0             3.0  ...
# 21122                          1.0             3.0  ...
#
#        club_contract_valid_until_19  league_level_19  club_team_id_19  \
# 2                            2022.0              1.0             45.0
# 4                            2023.0              1.0             10.0
# 6                            2022.0              1.0             73.0
# 9                            2024.0              1.0             18.0
# 10                           2021.0              1.0              5.0
# ...                             ...              ...              ...
# 19686                        2020.0              2.0              2.0
# 19722                        2018.0              1.0         110152.0
# 19735                        2021.0              2.0            573.0
# 19963                        2019.0              1.0             80.0
# 21122                        2020.0              1.0            702.0
#
#        weight_kg_19  height_cm_19  age_19  wage_eur_19  value_eur_19  \
# 2              83.0         187.0    33.0     400000.0    77000000.0
# 4              70.0         181.0    27.0     350000.0   102000000.0
# 6              73.0         178.0    19.0      80000.0    72000000.0
# 9              89.0         188.0    24.0     200000.0    86000000.0
# 10             68.0         168.0    27.0     225000.0    63000000.0
# ...             ...           ...     ...          ...           ...
# 19686          78.0         182.0    30.0      15000.0     2200000.0
# 19722          65.0         164.0    27.0       7000.0     3500000.0
# 19735          65.0         175.0    24.0       9000.0     7500000.0
# 19963          78.0         182.0    29.0       4000.0      850000.0
# 21122          75.0         174.0    23.0       3000.0     1100000.0
#
#        potential_19  overall_19
# 2              94.0        94.0
# 4              92.0        91.0
# 6              95.0        87.0
# 9              92.0        89.0
# 10             90.0        89.0
# ...             ...         ...
# 19686          72.0        72.0
# 19722          73.0        72.0
# 19735          79.0        74.0
# 19963          68.0        68.0
# 21122          75.0        67.0
#
# [295 rows x 64 columns]

# %%
df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')
df_22=df_22[['sofifa_id','value_eur']]
# Out:
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_36293/1779480134.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')

# %%
dfs=df.merge(df_22,on='sofifa_id',how='inner')

# %%
dfs=dfs[dfs['value_eur']!=0]
dfs
# Out:
#      sofifa_id  physic_21  defending_21  dribbling_21  passing_21  \
# 0        20801       77.0          35.0          89.0        81.0
# 1       192985       78.0          64.0          88.0        93.0
# 2       231747       76.0          39.0          91.0        78.0
# 3       202126       83.0          47.0          80.0        80.0
# 4       215914       82.0          86.0          81.0        76.0
# ..         ...        ...           ...           ...         ...
# 282     192624       64.0          62.0          68.0        63.0
# 283     217758       71.0          41.0          64.0        56.0
# 285     236047       69.0          65.0          56.0        55.0
# 286     186352       76.0          65.0          49.0        53.0
# 287     203338       64.0          60.0          61.0        56.0
#
#      shooting_21  pace_21  release_clause_eur_21  international_reputation_21  \
# 0           93.0     89.0             75900000.0                          5.0
# 1           86.0     76.0            161000000.0                          4.0
# 2           86.0     96.0            203100000.0                          3.0
# 3           91.0     68.0            140200000.0                          3.0
# 4           66.0     77.0             96900000.0                          3.0
# ..           ...      ...                    ...                          ...
# 282         57.0     76.0              1200000.0                          1.0
# 283         63.0     74.0               831000.0                          1.0
# 285         33.0     67.0               531000.0                          1.0
# 286         32.0     54.0               919000.0                          1.0
# 287         39.0     77.0               544000.0                          1.0
#
#      skill_moves_21  ...  league_level_19  club_team_id_19  weight_kg_19  \
# 0               5.0  ...              1.0             45.0          83.0
# 1               4.0  ...              1.0             10.0          70.0
# 2               5.0  ...              1.0             73.0          73.0
# 3               3.0  ...              1.0             18.0          89.0
# 4               2.0  ...              1.0              5.0          68.0
# ..              ...  ...              ...              ...           ...
# 282             3.0  ...              2.0             97.0          66.0
# 283             2.0  ...              2.0             15.0          85.0
# 285             2.0  ...              1.0            705.0          79.0
# 286             2.0  ...              1.0            694.0          82.0
# 287             2.0  ...              1.0         111651.0          75.0
#
#      height_cm_19  age_19  wage_eur_19  value_eur_19  potential_19  \
# 0           187.0    33.0     400000.0    77000000.0          94.0
# 1           181.0    27.0     350000.0   102000000.0          92.0
# 2           178.0    19.0      80000.0    72000000.0          95.0
# 3           188.0    24.0     200000.0    86000000.0          92.0
# 4           168.0    27.0     225000.0    63000000.0          90.0
# ..            ...     ...          ...           ...           ...
# 282         175.0    26.0       5000.0      700000.0          66.0
# 283         178.0    26.0       4000.0      825000.0          69.0
# 285         179.0    28.0       2000.0      240000.0          62.0
# 286         187.0    28.0       5000.0     1400000.0          70.0
# 287         180.0    27.0       2000.0      375000.0          64.0
#
#      overall_19    value_eur
# 0          94.0   45000000.0
# 1          91.0  125500000.0
# 2          87.0  194000000.0
# 3          89.0  129500000.0
# 4          89.0  100000000.0
# ..          ...          ...
# 282        66.0     750000.0
# 283        66.0     850000.0
# 285        62.0     425000.0
# 286        70.0     325000.0
# 287        64.0     425000.0
#
# [283 rows x 65 columns]

# %%
dfs=dfs.fillna(dfs.mean())
dfs.isnull().sum()
# Out:
# sofifa_id       0
# physic_21       0
# defending_21    0
# dribbling_21    0
# passing_21      0
#                ..
# wage_eur_19     0
# value_eur_19    0
# potential_19    0
# overall_19      0
# value_eur       0
# Length: 65, dtype: int64

# %%
X=dfs.drop(columns='value_eur')
y=dfs.value_eur

# %%
y
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 288 entries, 0 to 287
# Series name: value_eur
# Non-Null Count  Dtype
# --------------  -----
# 288 non-null    float64
# dtypes: float64(1)
# memory usage: 4.5 KB

# %%
from sklearn.model_selection import train_test_split
X_train22, X_test22, y_train22, y_test22 = train_test_split(X, y, test_size=0.3,random_state=10)

# %%
trainer=Trainer(X,y)
trainer.run()
y_pred=trainer.predict(X_test22)

# %%
pd.DataFrame(y_pred)
# Out:
#                0
# 0   4.212208e+06
# 1   1.124635e+07
# 2   1.586872e+06
# 3   6.438303e+05
# 4   2.213775e+07
# ..           ...
# 82  1.659578e+07
# 83  2.269269e+07
# 84  2.274580e+06
# 85  1.406162e+08
# 86  2.289033e+07
#
# [87 rows x 1 columns]
