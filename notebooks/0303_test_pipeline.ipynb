# %%
# %load_ext autoreload
# %autoreload 2

# %%
from opti_recruit.pipeline import Trainer
from opti_recruit.data import get_data,clean_data
import pandas as pd

# %%
df=pd.read_csv('df_all_d_new.csv',index_col=[0])
df=df.dropna(how='any')

# %%
df
# Out:
#        sofifa_id  physic_21  defending_21  dribbling_21  passing_21  \
# 2          20801       77.0          35.0          89.0        81.0
# 4         192985       78.0          64.0          88.0        93.0
# 6         231747       76.0          39.0          91.0        78.0
# 9         202126       83.0          47.0          80.0        80.0
# 10        215914       82.0          86.0          81.0        76.0
# ...          ...        ...           ...           ...         ...
# 19686     191005       70.0          67.0          69.0        71.0
# 19722     211338       71.0          63.0          72.0        70.0
# 19735     216468       57.0          43.0          71.0        72.0
# 19963     178233       68.0          59.0          71.0        65.0
# 21122     221662       65.0          55.0          67.0        63.0
#
#        shooting_21  pace_21  release_clause_eur_21  \
# 2             93.0     89.0             75900000.0
# ...

# %%
pd.set_option('display.max_columns', None)
df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')
df_22=df_22[['sofifa_id', 'physic', 'defending', 'dribbling', 'passing',
             'shooting', 'pace', 'release_clause_eur',
             'international_reputation', 'skill_moves', 'weak_foot',
             'club_contract_valid_until', 'league_level',
             'weight_kg', 'height_cm', 'age',
             'wage_eur', 'value_eur', 'potential', 'overall']]
df_22
# Out:
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_49972/3109639938.py:2: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')
#        sofifa_id  physic  defending  dribbling  passing  shooting  pace  \
# 0         158023    65.0       34.0       95.0     91.0      92.0  85.0
# 1         188545    82.0       44.0       86.0     79.0      92.0  78.0
# 2          20801    75.0       34.0       88.0     80.0      94.0  87.0
# 3         190871    63.0       37.0       94.0     86.0      83.0  91.0
# 4         192985    78.0       64.0       88.0     93.0      86.0  76.0
# ...          ...     ...        ...        ...      ...       ...   ...
# 19234     261962    49.0       42.0       48.0     46.0      35.0  58.0
# 19235     262040    51.0       41.0       46.0     50.0      39.0  59.0
# 19236     262760    52.0       41.0       49.0     45.0      37.0  60.0
# ...

# %%
#dfs=df.merge(df_22,on='sofifa_id',how='inner')

# %%
dfs=df_22[df_22['value_eur']!=0]
dfs
# Out:
#        sofifa_id  physic  defending  dribbling  passing  shooting  pace  \
# 0         158023    65.0       34.0       95.0     91.0      92.0  85.0
# 1         188545    82.0       44.0       86.0     79.0      92.0  78.0
# 2          20801    75.0       34.0       88.0     80.0      94.0  87.0
# 3         190871    63.0       37.0       94.0     86.0      83.0  91.0
# 4         192985    78.0       64.0       88.0     93.0      86.0  76.0
# ...          ...     ...        ...        ...      ...       ...   ...
# 19234     261962    49.0       42.0       48.0     46.0      35.0  58.0
# 19235     262040    51.0       41.0       46.0     50.0      39.0  59.0
# 19236     262760    52.0       41.0       49.0     45.0      37.0  60.0
# 19237     262820    42.0       15.0       48.0     36.0      46.0  68.0
# 19238     264540    48.0       36.0       48.0     45.0      38.0  68.0
#
#        release_clause_eur  international_reputation  skill_moves  weak_foot  \
# ...

# %%
dfs=dfs.fillna(dfs.mean())
dfs.isnull().sum()
# Out:
# sofifa_id                    0
# physic                       0
# defending                    0
# dribbling                    0
# passing                      0
# shooting                     0
# pace                         0
# release_clause_eur           0
# international_reputation     0
# skill_moves                  0
# weak_foot                    0
# club_contract_valid_until    0
# league_level                 0
# weight_kg                    0
# height_cm                    0
# age                          0
# wage_eur                     0
# value_eur                    0
# potential                    0
# overall                      0
# dtype: int64

# %%
X=dfs.drop(columns=['value_eur','sofifa_id'])
y=dfs.value_eur

# %%
y
# Out:
# 0         78000000.0
# 1        119500000.0
# 2         45000000.0
# 3        129000000.0
# 4        125500000.0
#             ...
# 19234        70000.0
# 19235       110000.0
# 19236       100000.0
# 19237       110000.0
# 19238       110000.0
# Name: value_eur, Length: 19239, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train22, X_test22, y_train22, y_test22 = train_test_split(X, y, test_size=0.3,random_state=10)

# %%
trainer=Trainer(X_train22,y_train22)

# %%
trainer

# %%
trainer.run()

# %%
y_pred=trainer.predict(X_test22)

# %%
pd.DataFrame(y_pred)
# Out:
#                  0
# 0     1.772964e+06
# 1     1.819739e+07
# 2     6.929951e+05
# 3     3.164025e+06
# 4     6.479508e+06
# ...            ...
# 5767  7.042620e+06
# 5768  7.675326e+05
# 5769  3.673898e+05
# 5770  1.693856e+05
# 5771  3.652390e+06
#
# [5772 rows x 1 columns]

# %%
import numpy as np

# %%
yt=np.log(y_test22)

# %%
predictions={'y_pred':np.log(y_pred),'y_true':yt}

# %%
new_df=pd.DataFrame(predictions).sort_index()
new_df.head(30)
# Out:
#         y_pred     y_true
# 0    19.382189  18.172219
# 7    17.424385  16.418200
# 9    19.854092  18.679191
# 13   19.348435  18.459901
# 16   19.318883  18.430631
# 39   18.685542  18.320860
# 40   18.851040  18.348110
# 42   18.693371  18.240357
# 43   19.610200  18.598827
# 44   19.488048  18.551709
# 48   16.395135  15.830414
# 51   18.149210  17.989898
# 53   17.494218  17.795192
# 55   17.959585  17.997561
# 56   17.613623  17.831894
# 58   18.228976  17.997561
# 59   18.004643  18.035018
# 68   18.348367  18.119576
# 76   16.737885  16.677711
# 79   17.389287  17.576711
# 82   17.762898  17.776324
# 83   17.527350  17.785802
# 85   18.052734  17.804495
# 87   17.876944  17.676240
# 90   18.288966  18.005165
# 99   16.718016  16.418200
# 100  16.732528  16.835935
# 103  16.681490  16.860033
# 113  17.205108  17.327056
# 115  17.043093  17.356470

# %%
trainer.evaluate(np.log(y_pred),np.log(y_test22))
# Out:
# 0.25

# %%
X_test={'physic':66.0, 'defending':37, 'dribbling':94, 'passing':90,
       'shooting':95, 'pace':88, 'release_clause_eur':145500000.0,
       'international_reputation':5, 'skill_moves':4, 'weak_foot':3,
       'club_contract_valid_until':2023, 'league_level':2,
       'weight_kg':73, 'height_cm':175, 'age':25,
       'wage_eur':270000.0,'potential':90, 'overall':88}

# %%
X_test=pd.DataFrame(data=X_test,index=[0])

# %%
X_test
# Out:
#    physic  defending  dribbling  passing  shooting  pace  release_clause_eur  \
# 0    66.0         37         94       90        95    88         145500000.0
#
#    international_reputation  skill_moves  weak_foot  \
# 0                         5            4          3
#
#    club_contract_valid_until  league_level  weight_kg  height_cm  age  \
# 0                       2023             2         73        175   25
#
#    wage_eur  potential  overall
# 0  270000.0         90       88

# %%
y_pred_new=trainer.predict(X_test)
y_pred
# Out:
# array([ 1772964.03712228, 18197390.03901683,   692995.12880263, ...,
#          367389.81961335,   169385.60387895,  3652390.33326425])

# %% [markdown]
# ## predict the value in 2023

# %%
# need sofifa 20~22
df_20=pd.read_csv('../raw_data/fifa22/players_20.csv')
df_21=pd.read_csv('../raw_data/fifa22/players_21.csv')
df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')
# Out:
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_49972/2204681879.py:4: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22=pd.read_csv('../raw_data/fifa22/players_22.csv')

# %%
df_22.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %%
dfs = [ df_20, df_21]

year = 20
columns=['long_name', 'club_logo_url','nation_flag_url','club_flag_url','nation_logo_url','player_face_url','dob','player_url', 'real_face','nation_jersey_number','nation_position']
df_22.drop(columns=columns, inplace=True)

df_22 = df_22.add_suffix('_22')

for frame in dfs:
    frame.drop(columns=columns, inplace=True)
    df_22 = df_22.join(frame, rsuffix=f"_{year}")
    year += 1

df_22
# Out:
#        sofifa_id_22       short_name_22 player_positions_22  overall_22  \
# 0            158023            L. Messi          RW, ST, CF          93
# 1            188545      R. Lewandowski                  ST          92
# 2             20801   Cristiano Ronaldo              ST, LW          91
# 3            190871           Neymar Jr             LW, CAM          91
# 4            192985        K. De Bruyne             CM, CAM          91
# ...             ...                 ...                 ...         ...
# 19234        261962           Song Defu                 CDM          47
# 19235        262040           C. Porter                  CM          47
# 19236        262760            N. Logue                  CM          47
# 19237        262820           L. Rudden                  ST          47
# 19238        264540  E. Lalchhanchhuaha                 CAM          47
#
#        potential_22  value_eur_22  wage_eur_22  age_22  height_cm_22  \
# ...

# %%
df_3y=df_22[['sofifa_id', 'physic', 'defending', 'dribbling', 'passing',
       'shooting', 'pace', 'release_clause_eur',
       'international_reputation', 'skill_moves', 'weak_foot',
       'club_contract_valid_until', 'league_level',
       'weight_kg', 'height_cm', 'age',
       'wage_eur', 'value_eur', 'potential', 'overall',
       'sofifa_id_22', 'physic_22', 'defending_22', 'dribbling_22', 'passing_22',
       'shooting_22', 'pace_22', 'release_clause_eur_22',
       'international_reputation_22', 'skill_moves_22', 'weak_foot_22',
       'club_contract_valid_until_22', 'league_level_22',
       'weight_kg_22', 'height_cm_22', 'age_22',
       'wage_eur_22', 'value_eur_22', 'potential_22', 'overall_22',
       'sofifa_id_21', 'physic_21', 'defending_21', 'dribbling_21', 'passing_21',
       'shooting_21', 'pace_21', 'release_clause_eur_21',
       'international_reputation_21', 'skill_moves_21', 'weak_foot_21',
       'club_contract_valid_until_21', 'league_level_21',
       'weight_kg_21', 'height_cm_21', 'age_21',
       'wage_eur_21', 'value_eur_21', 'potential_21', 'overall_21']]

# %%
df_3y
# Out:
#        sofifa_id  physic  defending  dribbling  passing  shooting  pace  \
# 0       158023.0    66.0       39.0       96.0     92.0      92.0  87.0
# 1        20801.0    78.0       35.0       89.0     82.0      93.0  90.0
# 2       190871.0    58.0       32.0       95.0     87.0      85.0  91.0
# 3       183277.0    66.0       35.0       94.0     86.0      83.0  91.0
# 4       192985.0    78.0       61.0       86.0     92.0      86.0  76.0
# ...          ...     ...        ...        ...      ...       ...   ...
# 19234        NaN     NaN        NaN        NaN      NaN       NaN   NaN
# 19235        NaN     NaN        NaN        NaN      NaN       NaN   NaN
# 19236        NaN     NaN        NaN        NaN      NaN       NaN   NaN
# 19237        NaN     NaN        NaN        NaN      NaN       NaN   NaN
# 19238        NaN     NaN        NaN        NaN      NaN       NaN   NaN
#
#        release_clause_eur  international_reputation  skill_moves  weak_foot  \
# ...

# %%
 df_3y=df_3y.dropna(how='any')

# %%
df_3y_test=df_3y.drop(columns=['sofifa_id','sofifa_id_21','sofifa_id_22'])

# %%
y_pred_2023=trainer.predict(df_3y_test)

# %%
dict={'value_eur_2023':np.log(y_pred_2023),
      'value_eur_22':np.log(df_3y_test['value_eur_22'])}

# %%
pd.DataFrame(dict).head(50)
# Out:
#     value_eur_2023  value_eur_22
# 0        20.415937     18.172219
# 1        19.426844     18.598827
# 2        20.226376     17.622173
# 3        20.039232     18.675323
# 4        19.871146     18.647816
# 9        19.400214     18.679191
# 11       18.809125     18.005165
# 13       18.733662     18.459901
# 14       18.778515     18.292847
# 17       19.342309     18.430631
# 19       19.401391     18.497642
# 22       20.158915     16.993564
# 23       18.069436     17.611000
# 27       18.001161     18.493001
# 28       18.142576     18.493001
# 30       18.786613     17.747336
# 32       18.418205     17.281246
# 35       19.314197     18.005165
# 36       19.276798     18.027638
# 39       19.082105     18.320860
# 40       17.437216     18.348110
# 41       17.209977     18.348110
# 42       18.286930     18.240357
# 43       17.608379     18.598827
# 44       17.701807     18.551709
# 45       17.841771     18.573402
# 46       17.826618     18.445373
# ...
