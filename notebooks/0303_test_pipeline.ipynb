# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of opti_recruit.pipeline failed: Traceback (most recent call last):
#   File "/Users/yifeisun/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/yifeisun/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 455, in superreload
#     module = reload(module)
#   File "/Users/yifeisun/.pyenv/versions/3.8.12/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 843, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
# ...

# %%
from opti_recruit.pipeline import func,set_pipeline,run,predict

# %%
from opti_recruit.data import clean_data

# %%
from opti_recruit.feature_engineering import feature_engineering
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 from opti_recruit.feature_engineering import feature_engineering
#
# File ~/code/yirki/opti_recruit/opti_recruit/feature_engineering.py:6, in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 6 from opti_recruit.data import load_data
#       8 def is_bench(d):
#       9     if d in ("SUB", "RES", ""):
#
# ImportError: cannot import name 'load_data' from 'opti_recruit.data' (/Users/yifeisun/code/yirki/opti_recruit/opti_recruit/data.py)

# %%
import pandas as pd

# %%
X=pd.read_csv('../raw_data/fifa22/players_22.csv')
# Out:
# /var/folders/w7/n5m3c1_n3mn3b92rk5hw7msc0000gn/T/ipykernel_33026/4144123557.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   X=pd.read_csv('../raw_data/fifa22/players_22.csv')

# %%
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...
