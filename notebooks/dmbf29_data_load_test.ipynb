# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of opti_recruit.data failed: Traceback (most recent call last):
#   File "/Users/dougberks/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/dougberks/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/dougberks/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/Users/dougberks/.pyenv/versions/3.8.12/envs/opti_recruit/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ...

# %%
from opti_recruit.data import get_data, clean_data

# %%
dfs = get_data()

# %%
dfs[17].head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 3     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name player_positions  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro       LW, LM, ST
# 1           L. Messi       Lionel Andrés Messi Cuccittini               RW
# 2           M. Neuer                   Manuel Peter Neuer               GK
# 3          L. Suárez             Luis Alberto Suárez Díaz               ST
# 4             Neymar        Neymar da Silva Santos Júnior               LW
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
dfs = clean_data(dfs)

# %%
df_17.head()
# Out:
#    sofifa_id         short_name player_positions  overall  potential  \
# 0      20801  Cristiano Ronaldo       LW, LM, ST       94         94
# 1     158023           L. Messi               RW       93         93
# 2     167495           M. Neuer               GK       92         92
# 3     176580          L. Suárez               ST       92         92
# 4     190871             Neymar               LW       92         95
#
#      value_eur  wage_eur  age  height_cm  weight_kg  ...  power_long_shots  \
# 0   87000000.0  575000.0   31        185         80  ...                92
# 1   89000000.0  575000.0   29        170         72  ...                88
# 2   69500000.0  225000.0   30        193         92  ...                16
# 3   83000000.0  525000.0   29        182         85  ...                86
# 4  109000000.0  450000.0   24        174         68  ...                77
#
#   mentality_aggression mentality_interceptions  mentality_positioning  \
# ...
